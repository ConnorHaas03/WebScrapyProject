# %% [markdown]
# # Scrapy Project Analyzing Zoo Data
# ## by Connor Haas

# %%
import pandas as pd
import numpy as np
import re
from matplotlib import pyplot as plt
import seaborn as sns
import csv

# %%
#extracting csv file with zoo name and data
zooDF = pd.read_csv(r'C:\Users\conma\Desktop\NYCDSA\Webscraping\ScrapyProject\zoo_data\zoodata.csv')
countryDF = pd.read_csv(r'C:\Users\conma\Desktop\NYCDSA\Webscraping\ScrapyProject\country_data\countrydata.csv')
revenueDF = pd.read_csv(r'C:\Users\conma\Desktop\NYCDSA\Webscraping\ScrapyProject\zoo_data\zoorev.csv')

# %%
revenueDF
# Out:
#              EIN                              Name               Address  \
# 0    951648219.0   ZOOLOGICAL SOCIETY OF SAN DIEGO         PO BOX 120551
# 1    131740011.0     WILDLIFE CONSERVATION SOCIETY    2300 SOUTHERN BLVD
# 2    363297716.0              OMAHA ZOO FOUNDATION        3701 S 10TH ST
# 3    942487469.0  MONTEREY BAY AQUARIUM FOUNDATION       886 CANNERY ROW
# 4    362167918.0            SHEDD AQUARIUM SOCIETY  1200 S LAKE SHORE DR
# ..           ...                               ...                   ...
# 808          NaN                               NaN                   NaN
# 809          NaN                               NaN                   NaN
# 810          NaN                               NaN                   NaN
# 811          NaN                               NaN                   NaN
# 812          NaN                               NaN                   NaN
#
#           City State         Zip       Revenue  Unnamed: 7
# 0    SAN DIEGO    CA  92112-0551  $294,950,888         NaN
# 1        BRONX    NY  10460-1068  $253,680,190         NaN
# 2        OMAHA    NE  68107-2299  $121,645,586         NaN
# 3     MONTEREY    CA  93940-1023  $100,827,641         NaN
# 4      CHICAGO    IL  60605-2402   $82,931,011         NaN
# ..         ...   ...         ...           ...         ...
# 808        NaN   NaN         NaN           NaN         NaN
# 809        NaN   NaN         NaN           NaN         NaN
# 810        NaN   NaN         NaN           NaN         NaN
# 811        NaN   NaN         NaN           NaN         NaN
# 812        NaN   NaN         NaN           NaN         NaN
#
# [813 rows x 8 columns]

# %%
zooDF
# Out:
#                   address            city        country  \
# 0             2070 Zoo Ln         Abilene  United States
# 1               1 Wild Pl      Birmingham  United States
# 2    USCD, 9500 Gilman Dr        La Jolla  United States
# 3        7400 Division Dr    Battle Creek  United States
# 4           PO Box FL 145  Flatts Village            NaN
# ..                    ...             ...            ...
# 245  23 Science Center Rd      Holderness  United States
# 246    2300 Southern Blvd           Bronx  United States
# 247             3414 W St          Eureka  United States
# 248   2222 Saint Paul St.       Rochester  United States
# 249       5555 W Zoo Blvd         Wichita  United States
#
#                                    name  \
# 0            Abilene Zoological Gardens
# 1                        Birmingham Zoo
# 2             Birch Aquarium at Scripps
# 3                       Binder Park Zoo
# 4      Bermuda Aquarium, Museum and Zoo
# ..                                  ...
# 245  Squam Lakes Natural Science Center
# 246                           Bronx Zoo
# 247                    Sequoia Park Zoo
# 248                     Seneca Park Zoo
# 249                 Sedgwick County Zoo
#
#                                               name_url  \
# 0    https://en.wikipedia.org/wiki/Abilene_Zoologic...
# 1         https://en.wikipedia.org/wiki/Birmingham_Zoo
# 2         https://en.wikipedia.org/wiki/Birch_Aquarium
# 3        https://en.wikipedia.org/wiki/Binder_Park_Zoo
# 4    https://en.wikipedia.org/wiki/Bermuda_Aquarium...
# ..                                                 ...
# 245  https://en.wikipedia.org/wiki/Squam_Lakes_Natu...
# 246            https://en.wikipedia.org/wiki/Bronx_Zoo
# 247     https://en.wikipedia.org/wiki/Sequoia_Park_Zoo
# 248      https://en.wikipedia.org/wiki/Seneca_Park_Zoo
# 249  https://en.wikipedia.org/wiki/Sedgwick_County_Zoo
#
#                     num_animals   num_species          state
# 0                          1100          >250          Texas
# 1                          ~800          200+        Alabama
# 2                        3,000+           380     California
# 3                           500           140       Michigan
# 4                           300           NaN        Bermuda
# ..                          ...           ...            ...
# 245                         NaN           NaN  New Hampshire
# 246                4,000 (2010)    650 (2010)       New York
# 247  Vertebrates: 195 (in 2013)  54 (in 2013)     California
# 248                         NaN           NaN       New York
# 249                       3,000           400         Kansas
#
# [250 rows x 8 columns]

# %%
countryDF
# Out:
#                                  city_2016_land_area  \
# 0  301.5 sq mi\n,468.7 sq mi\n,227.3 sq mi\n,637....
# 1  102.3 km,\n,69.9 km,\n,53.6 km,\n,79.5 km,\n,2...
# 2  120.996 km,\n,67.288 km,\n,86.381 km,\n,86.055...
# 3  2.30% from 2000 to 2010\n,annexed by , in 1907...
#
#                                            city_name  \
# 0  New York,[d],Los Angeles,Chicago,Houston,[3],P...
# 1             San Juan,Bayamón,Carolina,Ponce,Caguas
# 2  Nevada,Virginia,Nevada,Nevada,Louisiana,Califo...
# 3  New York,Pennsylvania,New York,New Jersey,Ohio...
#
#                                             pop_2018  \
# 0  8,398,748\n,3,990,456\n,2,705,994\n,2,325,502\...
# 1  395,326\n,208,116\n,176,762\n,166,327\n,142,893\n
# 2  186,070\n,189,453\n,156,120\n,117,390\n,146,13...
# 3   (1950)\n, (1900)\n, (1890)\n, (1950)\n, (1950...
#
#                                          pop_density  \
# 0  28,317/sq mi\n,8,484/sq mi\n,11,900/sq mi\n,3,...
# 1  3,297/km,\n,2,568/km,\n,2,881/km,\n,1,771/km,\...
# 2  1,844/km,\n,3,086/km,\n,2,192/km,\n,2,073/km,\...
# 3                                                NaN
#
#                                           state_name
# 0  New York,\n,California,\n,Illinois,\n,Texas,\n...
# 1                                                NaN
# 2                                                NaN
# 3                                                NaN

# %%
countryDF2 = pd.DataFrame([])
zooDF2 = pd.DataFrame([])
revenueDF2 = pd.DataFrame([])

# %%
#redefine zooDF2 with variable name changes
zooDF2['city_name'] = zooDF['city']
zooDF2['state_name'] = zooDF['state']
zooDF2['zoo_name'] = zooDF['name']
zooDF2['num_animals'] = zooDF['num_animals']
zooDF2['num_species'] = zooDF['num_species']
zooDF2
# Out:
#           city_name     state_name                            zoo_name  \
# 0           Abilene          Texas          Abilene Zoological Gardens
# 1        Birmingham        Alabama                      Birmingham Zoo
# 2          La Jolla     California           Birch Aquarium at Scripps
# 3      Battle Creek       Michigan                     Binder Park Zoo
# 4    Flatts Village        Bermuda    Bermuda Aquarium, Museum and Zoo
# ..              ...            ...                                 ...
# 245      Holderness  New Hampshire  Squam Lakes Natural Science Center
# 246           Bronx       New York                           Bronx Zoo
# 247          Eureka     California                    Sequoia Park Zoo
# 248       Rochester       New York                     Seneca Park Zoo
# 249         Wichita         Kansas                 Sedgwick County Zoo
#
#                     num_animals   num_species
# 0                          1100          >250
# 1                          ~800          200+
# 2                        3,000+           380
# 3                           500           140
# 4                           300           NaN
# ..                          ...           ...
# 245                         NaN           NaN
# 246                4,000 (2010)    650 (2010)
# 247  Vertebrates: 195 (in 2013)  54 (in 2013)
# 248                         NaN           NaN
# 249                       3,000           400
#
# [250 rows x 5 columns]

# %%
numSpec = zooDF2['num_species']
numSpec = numSpec.replace(r'\([^)]*\)',"",regex=True)
numSpec = numSpec.replace('[^0-9.]',"",regex=True)
zooDF2['num_species'] = numSpec

# %%
numAni = zooDF2['num_animals']
numAni = numAni.replace(r'\([^)]*\)',"",regex=True)
numAni = numAni.replace('[^0-9.]',"",regex=True)
zooDF2['num_animals'] = numAni
zooDF2
# Out:
#           city_name     state_name                            zoo_name  \
# 0           Abilene          Texas          Abilene Zoological Gardens
# 1        Birmingham        Alabama                      Birmingham Zoo
# 2          La Jolla     California           Birch Aquarium at Scripps
# 3      Battle Creek       Michigan                     Binder Park Zoo
# 4    Flatts Village        Bermuda    Bermuda Aquarium, Museum and Zoo
# ..              ...            ...                                 ...
# 245      Holderness  New Hampshire  Squam Lakes Natural Science Center
# 246           Bronx       New York                           Bronx Zoo
# 247          Eureka     California                    Sequoia Park Zoo
# 248       Rochester       New York                     Seneca Park Zoo
# 249         Wichita         Kansas                 Sedgwick County Zoo
#
#     num_animals num_species
# 0          1100         250
# 1           800         200
# 2          3000         380
# 3           500         140
# 4           300         NaN
# ..          ...         ...
# 245         NaN         NaN
# 246        4000         650
# 247         195          54
# 248         NaN         NaN
# 249        3000         400
#
# [250 rows x 5 columns]

# %%
#split landArea string and clean into dataframe
landArea = countryDF.loc[0,'city_2016_land_area'].split('\n')
#print("landArea", type(landArea))
landArea = list(map(lambda s: re.sub('[^0-9.]','',s),landArea))
landArea = list(map(lambda s: float(s),landArea[:-1]))
countryDF2['land_area'] = np.array(landArea)

#split city names string and clean into dataframe
city_name = countryDF.loc[0,'city_name'].split(',')
for e in city_name:
    if '[' in e:
        city_name.remove(e)
#np.array(city_name).size
countryDF2['city_name'] = np.array(city_name)

#split population of city and clean into dataframe
pop_2018 = countryDF.replace(',','',regex=True).loc[0,'pop_2018'].split('\n')
pop_2018 = list(map(lambda s: int(s),pop_2018[:-1]))
#np.array(pop_2018).size
countryDF2['pop_2018'] = np.array(pop_2018)

#split population denisty of city and clean into dataframe
popD = countryDF.loc[0,'pop_density'].replace(',','').split('\n')
popD = list(map(lambda s: re.sub('[^0-9]','',s),popD))
popD = list(map(lambda s: int(s), popD[:-1]))
#np.array(popD).size
countryDF2['population_density'] = np.array(popD)

#split states and clean into dataframe
state_name = countryDF.loc[0,'state_name'].split('\n')
state_name = list(map(lambda s: re.sub(r'[,_]','',s),state_name[:-1]))
#np.array(state_name).size
countryDF2['state_name']=np.array(state_name)

countryDF2
# Out:
#      land_area    city_name  pop_2018  population_density  state_name
# 0        301.5     New York   8398748               28317    New York
# 1        468.7  Los Angeles   3990456                8484  California
# 2        227.3      Chicago   2705994               11900    Illinois
# 3        637.5      Houston   2325502                3613       Texas
# 4        517.6      Phoenix   1660272                3120     Arizona
# ..         ...          ...       ...                 ...         ...
# 309       30.1       Edison    100693                3389  New Jersey
# 310       23.3   Woodbridge    100450                4351  New Jersey
# 311       59.9   San Angelo    100215                1681       Texas
# 312       28.0      Kenosha    100164                3577   Wisconsin
# 313       29.0    Vacaville    100154                3449  California
#
# [314 rows x 5 columns]

# %%
zooDF3 = zooDF2.merge(countryDF2,how = 'left', on = 'city_name')
zooDF3
# Out:
#           city_name state_name_x                          zoo_name  \
# 0           Abilene        Texas        Abilene Zoological Gardens
# 1        Birmingham      Alabama                    Birmingham Zoo
# 2          La Jolla   California         Birch Aquarium at Scripps
# 3      Battle Creek     Michigan                   Binder Park Zoo
# 4    Flatts Village      Bermuda  Bermuda Aquarium, Museum and Zoo
# ..              ...          ...                               ...
# 254           Bronx     New York                         Bronx Zoo
# 255          Eureka   California                  Sequoia Park Zoo
# 256       Rochester     New York                   Seneca Park Zoo
# 257       Rochester     New York                   Seneca Park Zoo
# 258         Wichita       Kansas               Sedgwick County Zoo
#
#     num_animals num_species  land_area  pop_2018  population_density  \
# 0          1100         250      106.7  122999.0              1146.0
# 1           800         200      146.1  209880.0              1452.0
# 2          3000         380        NaN       NaN                 NaN
# 3           500         140        NaN       NaN                 NaN
# 4           300         NaN        NaN       NaN                 NaN
# ..          ...         ...        ...       ...                 ...
# 254        4000         650        NaN       NaN                 NaN
# 255         195          54        NaN       NaN                 NaN
# 256         NaN         NaN       35.8  206284.0              5835.0
# 257         NaN         NaN       54.6  116961.0              2088.0
# 258        3000         400      160.4  389255.0              2431.0
#
#     state_name_y
# 0          Texas
# 1        Alabama
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 254          NaN
# 255          NaN
# 256     New York
# 257    Minnesota
# 258       Kansas
#
# [259 rows x 9 columns]

# %%
#redefine a new dataframe with less data
revenueDF2['rev'] = revenueDF['Revenue']
revenueDF2['city_name'] = revenueDF['City']
revenueDF2['zoo_name'] = revenueDF['Name']
rev = revenueDF2['rev']
rev = rev.replace('[^0-9.]',"",regex=True)
revenueDF2['rev'] = rev

# %%
bool_mask = revenueDF2["city_name"].isnull()
revenueDF2.loc[bool_mask, "city_name"] = ""

# %%
revenueDF2["city_name"] = pd.Series(list(map(lambda x: x.lower(), revenueDF2["city_name"])))

# %%
revenueDF2
# Out:
#            rev  city_name                          zoo_name
# 0    294950888  san diego   ZOOLOGICAL SOCIETY OF SAN DIEGO
# 1    253680190      bronx     WILDLIFE CONSERVATION SOCIETY
# 2    121645586      omaha              OMAHA ZOO FOUNDATION
# 3    100827641   monterey  MONTEREY BAY AQUARIUM FOUNDATION
# 4     82931011    chicago            SHEDD AQUARIUM SOCIETY
# ..         ...        ...                               ...
# 808        NaN                                          NaN
# 809        NaN                                          NaN
# 810        NaN                                          NaN
# 811        NaN                                          NaN
# 812        NaN                                          NaN
#
# [813 rows x 3 columns]

# %%
zooDF3['city_name'] = pd.DataFrame(list(map(lambda x: x.lower(), zooDF3.loc[:,'city_name'])))
zooDF3
# Out:
#           city_name state_name_x                          zoo_name  \
# 0           abilene        Texas        Abilene Zoological Gardens
# 1        birmingham      Alabama                    Birmingham Zoo
# 2          la jolla   California         Birch Aquarium at Scripps
# 3      battle creek     Michigan                   Binder Park Zoo
# 4    flatts village      Bermuda  Bermuda Aquarium, Museum and Zoo
# ..              ...          ...                               ...
# 254           bronx     New York                         Bronx Zoo
# 255          eureka   California                  Sequoia Park Zoo
# 256       rochester     New York                   Seneca Park Zoo
# 257       rochester     New York                   Seneca Park Zoo
# 258         wichita       Kansas               Sedgwick County Zoo
#
#     num_animals num_species  land_area  pop_2018  population_density  \
# 0          1100         250      106.7  122999.0              1146.0
# 1           800         200      146.1  209880.0              1452.0
# 2          3000         380        NaN       NaN                 NaN
# 3           500         140        NaN       NaN                 NaN
# 4           300         NaN        NaN       NaN                 NaN
# ..          ...         ...        ...       ...                 ...
# 254        4000         650        NaN       NaN                 NaN
# 255         195          54        NaN       NaN                 NaN
# 256         NaN         NaN       35.8  206284.0              5835.0
# 257         NaN         NaN       54.6  116961.0              2088.0
# 258        3000         400      160.4  389255.0              2431.0
#
#     state_name_y
# 0          Texas
# 1        Alabama
# 2            NaN
# 3            NaN
# 4            NaN
# ..           ...
# 254          NaN
# 255          NaN
# 256     New York
# 257    Minnesota
# 258       Kansas
#
# [259 rows x 9 columns]

# %%
zooDF4 = zooDF3.merge(revenueDF2, how='left', on= 'city_name')
zooDF4
# Out:
#         city_name state_name_x                  zoo_name_x num_animals  \
# 0         abilene        Texas  Abilene Zoological Gardens        1100
# 1         abilene        Texas  Abilene Zoological Gardens        1100
# 2      birmingham      Alabama              Birmingham Zoo         800
# 3        la jolla   California   Birch Aquarium at Scripps        3000
# 4    battle creek     Michigan             Binder Park Zoo         500
# ..            ...          ...                         ...         ...
# 415     rochester     New York             Seneca Park Zoo         NaN
# 416     rochester     New York             Seneca Park Zoo         NaN
# 417     rochester     New York             Seneca Park Zoo         NaN
# 418       wichita       Kansas         Sedgwick County Zoo        3000
# 419       wichita       Kansas         Sedgwick County Zoo        3000
#
#     num_species  land_area  pop_2018  population_density state_name_y  \
# 0           250      106.7  122999.0              1146.0        Texas
# 1           250      106.7  122999.0              1146.0        Texas
# 2           200      146.1  209880.0              1452.0      Alabama
# 3           380        NaN       NaN                 NaN          NaN
# 4           140        NaN       NaN                 NaN          NaN
# ..          ...        ...       ...                 ...          ...
# 415         NaN       35.8  206284.0              5835.0     New York
# 416         NaN       54.6  116961.0              2088.0    Minnesota
# 417         NaN       54.6  116961.0              2088.0    Minnesota
# 418         400      160.4  389255.0              2431.0       Kansas
# 419         400      160.4  389255.0              2431.0       Kansas
#
#           rev                                zoo_name_y
# 0     1695678                ABILENE ZOOLOGICAL SOCIETY
# 1      897910  GROVER NELSON PARK ZOOLOGICAL FOUNDATION
# 2         NaN                                       NaN
# 3         NaN                                       NaN
# 4     5372611        BINDER PARK ZOOLOGICAL SOCIETY INC
# ..        ...                                       ...
# 415      1647   SENECA ZOO SOCIETY DEVELOPMENT FUND INC
# 416   5027238                 SENECA ZOOLOGICAL SOCIETY
# 417      1647   SENECA ZOO SOCIETY DEVELOPMENT FUND INC
# 418  15161621    SEDGWICK COUNTY ZOOLOGICAL SOCIETY INC
# 419    395058     SEDGWICK COUNTY ZOOLOGICAL FOUNDATION
#
# [420 rows x 11 columns]

# %%
#mask to account for NaN values in my dataset
zooDF5 = zooDF4.copy()
zooDF5 

species_mask = zooDF5["num_species"].isnull()
zooDF5.loc[species_mask, "num_species"] = 0
zooDF5['num_species'] = pd.to_numeric(zooDF5['num_species'])

ani_mask = zooDF5["num_animals"].isnull()
zooDF5.loc[ani_mask,'num_animals'] = 0
zooDF5['num_animals'] = pd.to_numeric(zooDF5['num_animals'])

rev_mask = zooDF5['rev'].isnull()
zooDF5.loc[rev_mask,'rev']=0
zooDF5['rev'] = pd.to_numeric(zooDF5['rev'])

pop_mask = zooDF5["pop_2018"].isnull()
zooDF5.loc[pop_mask,'pop_2018']=0

popD_mask = zooDF5['population_density'].isnull()
zooDF5.loc[popD_mask,'population_density']=0

zooDF5.columns = ['City Name', 'State', 'Zoo Name', 'Number of Animals', 'Number of Species',
       'Area per sq mi', 'Population', 'Population Density', 'State_x', 'Revenue',
       'Zoo Name_x']

zooDF5
# zooDF5.loc[name_mask,'zoo_name_x'].count()
#zoo_plot = zooDF5.copy()
# Out:
#         City Name       State                    Zoo Name  Number of Animals  \
# 0         abilene       Texas  Abilene Zoological Gardens             1100.0
# 1         abilene       Texas  Abilene Zoological Gardens             1100.0
# 2      birmingham     Alabama              Birmingham Zoo              800.0
# 3        la jolla  California   Birch Aquarium at Scripps             3000.0
# 4    battle creek    Michigan             Binder Park Zoo              500.0
# ..            ...         ...                         ...                ...
# 415     rochester    New York             Seneca Park Zoo                0.0
# 416     rochester    New York             Seneca Park Zoo                0.0
# 417     rochester    New York             Seneca Park Zoo                0.0
# 418       wichita      Kansas         Sedgwick County Zoo             3000.0
# 419       wichita      Kansas         Sedgwick County Zoo             3000.0
#
#      Number of Species  Area per sq mi  Population  Population Density  \
# 0                250.0           106.7    122999.0              1146.0
# 1                250.0           106.7    122999.0              1146.0
# 2                200.0           146.1    209880.0              1452.0
# 3                380.0             NaN         0.0                 0.0
# 4                140.0             NaN         0.0                 0.0
# ..                 ...             ...         ...                 ...
# 415                0.0            35.8    206284.0              5835.0
# 416                0.0            54.6    116961.0              2088.0
# 417                0.0            54.6    116961.0              2088.0
# 418              400.0           160.4    389255.0              2431.0
# 419              400.0           160.4    389255.0              2431.0
#
#        State_x   Revenue                                Zoo Name_x
# 0        Texas   1695678                ABILENE ZOOLOGICAL SOCIETY
# 1        Texas    897910  GROVER NELSON PARK ZOOLOGICAL FOUNDATION
# 2      Alabama         0                                       NaN
# 3          NaN         0                                       NaN
# 4          NaN   5372611        BINDER PARK ZOOLOGICAL SOCIETY INC
# ..         ...       ...                                       ...
# 415   New York      1647   SENECA ZOO SOCIETY DEVELOPMENT FUND INC
# 416  Minnesota   5027238                 SENECA ZOOLOGICAL SOCIETY
# 417  Minnesota      1647   SENECA ZOO SOCIETY DEVELOPMENT FUND INC
# 418     Kansas  15161621    SEDGWICK COUNTY ZOOLOGICAL SOCIETY INC
# 419     Kansas    395058     SEDGWICK COUNTY ZOOLOGICAL FOUNDATION
#
# [420 rows x 11 columns]

# %%
zooDF5.sort_values(['Revenue'],ascending=False).reset_index(drop=True)
# Out:
#        City Name           State                              Zoo Name  \
# 0      san diego      California                         San Diego Zoo
# 1      san diego      California                    SeaWorld San Diego
# 2          bronx        New York                             Bronx Zoo
# 3          omaha        Nebraska              Omaha's Henry Doorly Zoo
# 4       monterey      California                 Monterey Bay Aquarium
# ..           ...             ...                                   ...
# 415      toronto         Ontario                           Toronto Zoo
# 416    asheville  North Carolina  Western North Carolina Nature Center
# 417       albany         Georgia                           Chehaw Park
# 418  brownsville           Texas                     Gladys Porter Zoo
# 419   pittsburgh    Pennsylvania                       National Aviary
#
#      Number of Animals  Number of Species  Area per sq mi  Population  \
# 0               3700.0              650.0           325.2   1425976.0
# 1                  0.0                0.0           325.2   1425976.0
# 2               4000.0              650.0             NaN         0.0
# 3                962.0                0.0           133.2    468262.0
# 4              35000.0              550.0             NaN         0.0
# ..                 ...                ...             ...         ...
# 415             5000.0              460.0             NaN         0.0
# 416              100.0                0.0             NaN         0.0
# 417              212.0               55.0             NaN         0.0
# 418             1600.0              400.0           132.5    183392.0
# 419              600.0              200.0            55.4    301048.0
#
#      Population Density       State_x    Revenue  \
# 0                4325.0    California  294950888
# 1                4325.0    California  294950888
# 2                   0.0           NaN  253680190
# 3                3356.0      Nebraska  121645586
# 4                   0.0           NaN  100827641
# ..                  ...           ...        ...
# 415                 0.0           NaN          0
# 416                 0.0           NaN          0
# 417                 0.0           NaN          0
# 418              1387.0         Texas          0
# 419              5481.0  Pennsylvania          0
#
#                                   Zoo Name_x
# 0            ZOOLOGICAL SOCIETY OF SAN DIEGO
# 1            ZOOLOGICAL SOCIETY OF SAN DIEGO
# 2              WILDLIFE CONSERVATION SOCIETY
# 3                       OMAHA ZOO FOUNDATION
# 4           MONTEREY BAY AQUARIUM FOUNDATION
# ..                                       ...
# 415                                      NaN
# 416                                      NaN
# 417                                      NaN
# 418  DOCENT COUNCIL OF THE GLADYS PORTER ZOO
# 419  GREATER PITTSBURGH AQUARIUM SOCIETY INC
#
# [420 rows x 11 columns]

# %%
#Highest Revenue
zooDF6 = zooDF5.copy()
zooDF6 = zooDF6.sort_values(['Revenue'],ascending=False).reset_index(drop=True)
sort_ = zooDF6[:40]
plt.figure(figsize=(16,12))
sns.set(font_scale=1.5)
sns.barplot(y=sort_['Zoo Name'], x=sort_['Revenue'], data=sort_).set_title("Zoo's with highest revenue")
# Out:
# Text(0.5, 1.0, "Zoo's with highest revenue")

# %%
specAniDF = zooDF5.copy()
specAniDF['ratio'] = specAniDF["Number of Species"]/specAniDF['Number of Animals']

plt.figure(figsize=(16,10))
sns.set(font_scale=1.5)
sns.scatterplot(x=specAniDF['Revenue'], y=specAniDF['ratio'], data=specAniDF).set_title("Ratio of Species to Animal vs. Revenue")
# Out:
# Text(0.5, 1.0, 'Ratio of Species to Animal vs. Revenue')

# %%
aniRevDF = zooDF5.copy()

plt.figure(figsize=(16,10))
sns.set(font_scale=1.5)
sns.scatterplot(x=aniRevDF['Revenue'], y=aniRevDF['Number of Animals'], data=aniRevDF, ci= None).set_title("Animal Count vs. Revenue")
# Out:
# Text(0.5, 1.0, 'Animal Count vs. Revenue')

# %%
landArea = countryDF.loc[0,'city_2016_land_area'].split('\n')
landArea = list(map(lambda s: re.sub('[^0-9.]','',s),landArea))
landArea = list(map(lambda s: float(s),landArea[:-1]))
countryDF2['land_area'] = np.array(landArea)
countryDF2
# Out:
#        city_name  pop_2018  Population_Density  land_area
# 0       New York   8398748               28317      301.5
# 1    Los Angeles   3990456                8484      468.7
# 2        Chicago   2705994               11900      227.3
# 3        Houston   2325502                3613      637.5
# 4        Phoenix   1660272                3120      517.6
# ..           ...       ...                 ...        ...
# 309       Edison    100693                3389       30.1
# 310   Woodbridge    100450                4351       23.3
# 311   San Angelo    100215                1681       59.9
# 312      Kenosha    100164                3577       28.0
# 313    Vacaville    100154                3449       29.0
#
# [314 rows x 4 columns]

# %%
city_name = countryDF.loc[0,'city_name'].split(',')
for e in city_name:
    if '[' in e:
        city_name.remove(e)
np.array(city_name).size
countryDF2['city_name'] = np.array(city_name)
countryDF2
# Out:
#        city_name
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4        Phoenix
# ..           ...
# 309       Edison
# 310   Woodbridge
# 311   San Angelo
# 312      Kenosha
# 313    Vacaville
#
# [314 rows x 1 columns]

# %%
pop_2018 = countryDF.replace(',','',regex=True).loc[0,'pop_2018'].split('\n')
pop_2018 = list(map(lambda s: int(s),pop_2018[:-1]))
np.array(pop_2018).size
countryDF2['pop_2018'] = np.array(pop_2018)
countryDF2
# Out:
#        city_name  pop_2018
# 0       New York   8398748
# 1    Los Angeles   3990456
# 2        Chicago   2705994
# 3        Houston   2325502
# 4        Phoenix   1660272
# ..           ...       ...
# 309       Edison    100693
# 310   Woodbridge    100450
# 311   San Angelo    100215
# 312      Kenosha    100164
# 313    Vacaville    100154
#
# [314 rows x 2 columns]

# %%
popD = countryDF.loc[0,'pop_density'].replace(',','').split('\n')
popD = list(map(lambda s: re.sub('[^0-9]','',s),popD))
popD = list(map(lambda s: int(s), popD[:-1]))
np.array(popD).size
countryDF2['Population_Density'] = np.array(popD)
countryDF2
# Out:
#        city_name  pop_2018  Population_Density
# 0       New York   8398748               28317
# 1    Los Angeles   3990456                8484
# 2        Chicago   2705994               11900
# 3        Houston   2325502                3613
# 4        Phoenix   1660272                3120
# ..           ...       ...                 ...
# 309       Edison    100693                3389
# 310   Woodbridge    100450                4351
# 311   San Angelo    100215                1681
# 312      Kenosha    100164                3577
# 313    Vacaville    100154                3449
#
# [314 rows x 3 columns]

# %%
state_name = countryDF.loc[0,'state_name'].split('\n')
state_name = list(map(lambda s: re.sub(r'[,_]','',s),state_name[:-1]))
np.array(state_name).size
countryDF2['state_name']=np.array(state_name)
