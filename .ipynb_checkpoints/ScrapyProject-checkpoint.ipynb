# %% [markdown]
# # Scrapy Project Analyzing Zoo Data
# ## by Connor Haas

# %%
import pandas as pd
import numpy as np
import re

# %%
import csv
#extracting csv file with zoo name and data
zooDF = pd.read_csv(r'C:\Users\conma\Desktop\NYCDSA\Webscraping\ScrapyProject\zoo_data\zoodata.csv')
countryDF = pd.read_csv(r'C:\Users\conma\Desktop\NYCDSA\Webscraping\ScrapyProject\country_data\countrydata.csv')

# %%
zooDF
# Out:
#                   address            city        country  \
# 0             2070 Zoo Ln         Abilene  United States
# 1    701 Whirlpool Street        New York  United States
# 2        2595 Roblin Blvd        Winnipeg         Canada
# 3        500 Edgewood Ave           Akron  United States
# 4        11 Oriente #2407          Puebla         Mexico
# ..                    ...             ...            ...
# 245  2600 Deweese Parkway          Dayton  United States
# 246        7401 SW 9th St      Des Moines  United States
# 247  USCD, 9500 Gilman Dr        La Jolla  United States
# 248      7400 Division Dr    Battle Creek  United States
# 249         PO Box FL 145  Flatts Village            NaN
#
#                                  name  \
# 0          Abilene Zoological Gardens
# 1                 Aquarium of Niagara
# 2                Assiniboine Park Zoo
# 3               Akron Zoological Park
# 4                 Africam Safari Park
# ..                                ...
# 245     Boonshoft Museum of Discovery
# 246                    Blank Park Zoo
# 247         Birch Aquarium at Scripps
# 248                   Binder Park Zoo
# 249  Bermuda Aquarium, Museum and Zoo
#
#                                               name_url num_animals  \
# 0    https://en.wikipedia.org/wiki/Abilene_Zoologic...        1100
# 1    https://en.wikipedia.org/wiki/Aquarium_of_Niagara         NaN
# 2    https://en.wikipedia.org/wiki/Assiniboine_Park...         200
# 3              https://en.wikipedia.org/wiki/Akron_Zoo         700
# 4    https://en.wikipedia.org/wiki/Africam_Safari_Park        2500
# ..                                                 ...         ...
# 245  https://en.wikipedia.org/wiki/Boonshoft_Museum...         NaN
# 246       https://en.wikipedia.org/wiki/Blank_Park_Zoo       1,484
# 247       https://en.wikipedia.org/wiki/Birch_Aquarium      3,000+
# 248      https://en.wikipedia.org/wiki/Binder_Park_Zoo         500
# 249  https://en.wikipedia.org/wiki/Bermuda_Aquarium...         300
#
#     num_species       state
# 0          1100       Texas
# 1           NaN    New York
# 2           200    Manitoba
# 3           700        Ohio
# 4          2500      Puebla
# ..          ...         ...
# 245         NaN        Ohio
# 246       1,484        Iowa
# 247      3,000+  California
# 248         500    Michigan
# 249         300     Bermuda
#
# [250 rows x 8 columns]

# %%
countryDF
# Out:
#                                  city_2016_land_area  \
# 0  301.5 sq mi\n,468.7 sq mi\n,227.3 sq mi\n,637....
# 1  102.3 km,\n,69.9 km,\n,53.6 km,\n,79.5 km,\n,2...
# 2  120.996 km,\n,67.288 km,\n,86.381 km,\n,86.055...
# 3  2.30% from 2000 to 2010\n,annexed by , in 1907...
#
#                                            city_name  \
# 0  New York,[d],Los Angeles,Chicago,Houston,[3],P...
# 1             San Juan,Bayamón,Carolina,Ponce,Caguas
# 2  Nevada,Virginia,Nevada,Nevada,Louisiana,Califo...
# 3  New York,Pennsylvania,New York,New Jersey,Ohio...
#
#                                             pop_2018  \
# 0  8,398,748\n,3,990,456\n,2,705,994\n,2,325,502\...
# 1  395,326\n,208,116\n,176,762\n,166,327\n,142,893\n
# 2  186,070\n,189,453\n,156,120\n,117,390\n,146,13...
# 3   (1950)\n, (1900)\n, (1890)\n, (1950)\n, (1950...
#
#                                          pop_density
# 0  28,317/sq mi\n,8,484/sq mi\n,11,900/sq mi\n,3,...
# 1  3,297/km,\n,2,568/km,\n,2,881/km,\n,1,771/km,\...
# 2  1,844/km,\n,3,086/km,\n,2,192/km,\n,2,073/km,\...
# 3                                                NaN

# %%
countryDF2 = pd.DataFrame([])
zooDF2 = pd.DataFrame([])

# %%
zooDF2['city_name'] = zooDF['city']
zooDF2['state'] = zooDF['state']
zooDF2['zoo_name'] = zooDF['name']
zooDF2['num_animals'] = zooDF['num_animals']
zooDF2['num_species'] = zooDF['num_species']
zooDF2
# Out:
#           city_name       state                          zoo_name num_animals  \
# 0           Abilene       Texas        Abilene Zoological Gardens        1100
# 1          New York    New York               Aquarium of Niagara         NaN
# 2          Winnipeg    Manitoba              Assiniboine Park Zoo         200
# 3             Akron        Ohio             Akron Zoological Park         700
# 4            Puebla      Puebla               Africam Safari Park        2500
# ..              ...         ...                               ...         ...
# 245          Dayton        Ohio     Boonshoft Museum of Discovery         NaN
# 246      Des Moines        Iowa                    Blank Park Zoo       1,484
# 247        La Jolla  California         Birch Aquarium at Scripps      3,000+
# 248    Battle Creek    Michigan                   Binder Park Zoo         500
# 249  Flatts Village     Bermuda  Bermuda Aquarium, Museum and Zoo         300
#
#     num_species
# 0          1100
# 1           NaN
# 2           200
# 3           700
# 4          2500
# ..          ...
# 245         NaN
# 246       1,484
# 247      3,000+
# 248         500
# 249         300
#
# [250 rows x 5 columns]

# %%
#split landArea string and clean into dataframe
landArea = countryDF.loc[0,'city_2016_land_area'].split('\n')
landArea = list(map(lambda s: re.sub('[^0-9.]','',s),landArea))
landArea = list(map(lambda s: float(s),landArea[:-1]))
countryDF2['land_area'] = np.array(landArea)

#split city names string and clean into dataframe
city_name = countryDF.loc[0,'city_name'].split(',')
for e in city_name:
    if '[' in e:
        city_name.remove(e)
np.array(city_name).size
countryDF2['city_name'] = np.array(city_name)

#split population of city and clean into dataframe
pop_2018 = countryDF.replace(',','',regex=True).loc[0,'pop_2018'].split('\n')
pop_2018 = list(map(lambda s: int(s),pop_2018[:-1]))
np.array(pop_2018).size
countryDF2['pop_2018'] = np.array(pop_2018)

popD = countryDF.loc[0,'pop_density'].replace(',','').split('\n')
popD = list(map(lambda s: re.sub('[^0-9]','',s),popD))
popD = list(map(lambda s: int(s), popD[:-1]))
np.array(popD).size
countryDF2['population_density'] = np.array(popD)

countryDF2
# Out:
#      land_area    city_name  pop_2018  population_density
# 0        301.5     New York   8398748               28317
# 1        468.7  Los Angeles   3990456                8484
# 2        227.3      Chicago   2705994               11900
# 3        637.5      Houston   2325502                3613
# 4        517.6      Phoenix   1660272                3120
# ..         ...          ...       ...                 ...
# 309       30.1       Edison    100693                3389
# 310       23.3   Woodbridge    100450                4351
# 311       59.9   San Angelo    100215                1681
# 312       28.0      Kenosha    100164                3577
# 313       29.0    Vacaville    100154                3449
#
# [314 rows x 4 columns]

# %%
#zooDF3 = zooDF2
# zooDF3['city_name'] = pd.DataFrame(list(map(lambda x: x.lower(), zooDF2.loc[:,'city_name'])))
# countryDF3 = countryDF2
# countryDF3['city_name'] = pd.DataFrame(list(map(lambda x: x.lower(), countryDF2.loc[:,'city_name'])))
zooDF3 = zooDF2.merge(countryDF2,how = 'left', on = 'city_name')
zooDF3
#list(zooDF3[zooDF3.pop_2018.isna()]['city_name'])
# Out:
#           city_name       state                          zoo_name num_animals  \
# 0           Abilene       Texas        Abilene Zoological Gardens        1100
# 1          New York    New York               Aquarium of Niagara         NaN
# 2          Winnipeg    Manitoba              Assiniboine Park Zoo         200
# 3             Akron        Ohio             Akron Zoological Park         700
# 4            Puebla      Puebla               Africam Safari Park        2500
# ..              ...         ...                               ...         ...
# 254          Dayton        Ohio     Boonshoft Museum of Discovery         NaN
# 255      Des Moines        Iowa                    Blank Park Zoo       1,484
# 256        La Jolla  California         Birch Aquarium at Scripps      3,000+
# 257    Battle Creek    Michigan                   Binder Park Zoo         500
# 258  Flatts Village     Bermuda  Bermuda Aquarium, Museum and Zoo         300
#
#     num_species  land_area   pop_2018  population_density
# 0          1100      106.7   122999.0              1146.0
# 1           NaN      301.5  8398748.0             28317.0
# 2           200        NaN        NaN                 NaN
# 3           700       62.0   198006.0              3188.0
# 4          2500        NaN        NaN                 NaN
# ..          ...        ...        ...                 ...
# 254         NaN       55.7   140640.0              2522.0
# 255       1,484       88.9   216853.0              2424.0
# 256      3,000+        NaN        NaN                 NaN
# 257         500        NaN        NaN                 NaN
# 258         300        NaN        NaN                 NaN
#
# [259 rows x 8 columns]

# %%
landArea = countryDF.loc[0,'city_2016_land_area'].split('\n')
landArea = list(map(lambda s: re.sub('[^0-9.]','',s),landArea))
landArea = list(map(lambda s: float(s),landArea[:-1]))
countryDF2['land_area'] = np.array(landArea)
countryDF2
# Out:
#        city_name  pop_2018  Population_Density  land_area
# 0       New York   8398748               28317      301.5
# 1    Los Angeles   3990456                8484      468.7
# 2        Chicago   2705994               11900      227.3
# 3        Houston   2325502                3613      637.5
# 4        Phoenix   1660272                3120      517.6
# ..           ...       ...                 ...        ...
# 309       Edison    100693                3389       30.1
# 310   Woodbridge    100450                4351       23.3
# 311   San Angelo    100215                1681       59.9
# 312      Kenosha    100164                3577       28.0
# 313    Vacaville    100154                3449       29.0
#
# [314 rows x 4 columns]

# %%
city_name = countryDF.loc[0,'city_name'].split(',')
for e in city_name:
    if '[' in e:
        city_name.remove(e)
np.array(city_name).size
countryDF2['city_name'] = np.array(city_name)
countryDF2
# Out:
#        city_name
# 0       New York
# 1    Los Angeles
# 2        Chicago
# 3        Houston
# 4        Phoenix
# ..           ...
# 309       Edison
# 310   Woodbridge
# 311   San Angelo
# 312      Kenosha
# 313    Vacaville
#
# [314 rows x 1 columns]

# %%
pop_2018 = countryDF.replace(',','',regex=True).loc[0,'pop_2018'].split('\n')
pop_2018 = list(map(lambda s: int(s),pop_2018[:-1]))
np.array(pop_2018).size
countryDF2['pop_2018'] = np.array(pop_2018)
countryDF2
# Out:
#        city_name  pop_2018
# 0       New York   8398748
# 1    Los Angeles   3990456
# 2        Chicago   2705994
# 3        Houston   2325502
# 4        Phoenix   1660272
# ..           ...       ...
# 309       Edison    100693
# 310   Woodbridge    100450
# 311   San Angelo    100215
# 312      Kenosha    100164
# 313    Vacaville    100154
#
# [314 rows x 2 columns]

# %%
popD = countryDF.loc[0,'pop_density'].replace(',','').split('\n')
popD = list(map(lambda s: re.sub('[^0-9]','',s),popD))
popD = list(map(lambda s: int(s), popD[:-1]))
np.array(popD).size
countryDF2['Population_Density'] = np.array(popD)
countryDF2
# Out:
#        city_name  pop_2018  Population_Density
# 0       New York   8398748               28317
# 1    Los Angeles   3990456                8484
# 2        Chicago   2705994               11900
# 3        Houston   2325502                3613
# 4        Phoenix   1660272                3120
# ..           ...       ...                 ...
# 309       Edison    100693                3389
# 310   Woodbridge    100450                4351
# 311   San Angelo    100215                1681
# 312      Kenosha    100164                3577
# 313    Vacaville    100154                3449
#
# [314 rows x 3 columns]
